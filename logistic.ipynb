# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

data=pd.read_csv('C:\Users\Ananya\Desktop\diabetes.csv')
# Out:
#   File "<ipython-input-1-09c65c45169d>", line 8
#     data=pd.read_csv('C:\Users\Ananya\Desktop\diabetes.csv')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %%
data1=pd.read_csv('C:/Users/Ananya/Desktop/diabetes.csv')

# %%
 data1.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
data1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.countplot(x="Outcome",data)
# Out:
#   File "<ipython-input-6-c043d8f43ee5>", line 1
#     sns.countplot(x="Outcome",data)
#                               ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.countplot(x="Outcome",data_out=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0c709f5428d1> in <module>
# ----> 1 sns.countplot(x="Outcome",data_out=data)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3583         raise ValueError("Cannot pass values for both `x` and `y`")
#    3584
# -> 3585     plotter = _CountPlotter(
#    3586         x, y, hue, data, order, hue_order,
#    3587         estimator, ci, n_boot, units, seed,
#
# ...

# %%
sns.countplot(x="Outcome",data1=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-60bb3c3c9817> in <module>
# ----> 1 sns.countplot(x="Outcome",data1=data)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3583         raise ValueError("Cannot pass values for both `x` and `y`")
#    3584
# -> 3585     plotter = _CountPlotter(
#    3586         x, y, hue, data, order, hue_order,
#    3587         estimator, ci, n_boot, units, seed,
#
# ...

# %%
sns.countplot(x="Outcome",data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x="Outcome", hns="Age",data=data1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e8544173ff85> in <module>
# ----> 1 sns.countplot(x="Outcome", hns="Age",data=data1)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3595         ax = plt.gca()
#    3596
# -> 3597     plotter.plot(ax, kwargs)
#    3598     return ax
#    3599
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# ...

# %%
sns.countplot(x="Outcome", hne="Age",data=data1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-792842a35212> in <module>
# ----> 1 sns.countplot(x="Outcome", hne="Age",data=data1)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3595         ax = plt.gca()
#    3596
# -> 3597     plotter.plot(ax, kwargs)
#    3598     return ax
#    3599
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# ...

# %%
sns.countplot(x="Outcome", hue="Age",data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x="Outcome", hue="BloodPressure",data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x="Outcome", hue="BMI",data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
data1["Age"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data1["BMI"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data1.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
data1.isnull.isany()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-00c1b00c15db> in <module>
# ----> 1 data1.isnull.isany()
#
# AttributeError: 'function' object has no attribute 'isany'

# %%
data1.isnull().values.any()
# Out:
# False

# %%
sns.countplot(x="Outcome", hue="Pregnancies",data=data1)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.heatmap(data1.corr())
# Out:
# <AxesSubplot:>

# %%
x=data1.drop(["Outcome","BloodPressure"],axis=1)
y=data1["Outcome"]

# %%
corr=data1.corr()
print(corr)
sns.heatmap(data1.corr())
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions=logmodel.predict(x_test)

# %% [markdown]
# # #to check accuracy

# %%
score=logmodel.score(x_test,y_test)
score
# Out:
# 0.7748917748917749

# %% [markdown]
# #to check accuracy using confusion matrix

# %% [markdown]
# ##to check accuracy using confusion matrix

# %%
from sklearn import metrics
cm=metrics.confusion_matrix(y_test,predictions)
cm
# Out:
# array([[142,  15],
#        [ 37,  37]], dtype=int64)
